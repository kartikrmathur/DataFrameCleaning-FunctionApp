# %%
import pandas as pd
import numpy as np
#make df
df = pd.read_excel(r'D:\Function App Files\Open Opportunities Funnel-Dec21.xlsx',header = 1)
display(df)
# Out:
#     Unnamed: 0                          Open Opportunities Funnel  \
# 0          NaN  As of 2021-12-22 17:23:15 India Standard Time/...
# 1          NaN                                                NaN
# 2          NaN      Opportunity: Opportunity Owner: User Region →
# 3          NaN        Opportunity: Opportunity Owner: Full Name →
# 4          NaN                              Opportunity: Stage  ↑
# 5          NaN                                           Prospect
# 6          NaN                                      Proposal sent
# 7          NaN                                           Pipeline
# 8          NaN                                         Projection
# 9          NaN                                             Booked
# 10         NaN                                              Total
#
#                       Unnamed: 2                    Unnamed: 3  \
# 0                            NaN                           NaN
# ...

# %%
#transpose on df and store to df1
df = df.transpose()
display(df)
# Out:
#                                                                           0   \
# Unnamed: 0                                                               NaN
# Open Opportunities Funnel  As of 2021-12-22 17:23:15 India Standard Time/...
# Unnamed: 2                                                               NaN
# Unnamed: 3                                                               NaN
# Unnamed: 4                                                               NaN
# Unnamed: 5                                                               NaN
# Unnamed: 6                                                               NaN
# Unnamed: 7                                                               NaN
# Unnamed: 8                                                               NaN
# Unnamed: 9                                                               NaN
# Unnamed: 10                                                              NaN
# ...

# %%
display(df.iloc[1])
# Out:
# 0     As of 2021-12-22 17:23:15 India Standard Time/...
# 1                                                   NaN
# 2         Opportunity: Opportunity Owner: User Region →
# 3           Opportunity: Opportunity Owner: Full Name →
# 4                                 Opportunity: Stage  ↑
# 5                                              Prospect
# 6                                         Proposal sent
# 7                                              Pipeline
# 8                                            Projection
# 9                                                Booked
# 10                                                Total
# Name: Open Opportunities Funnel, dtype: object

# %%
#regex replace Space To UnderScore
df.iloc[1] = df.iloc[1].replace(' ', '_', regex=True)

# %%
#drop null
df = df.dropna(how='all')
display(df)
# Out:
#                                                                           0   \
# Open Opportunities Funnel  As_of_2021-12-22_17:23:15_India_Standard_Time/...
# Unnamed: 2                                                               NaN
# Unnamed: 3                                                               NaN
# Unnamed: 4                                                               NaN
# Unnamed: 5                                                               NaN
# Unnamed: 6                                                               NaN
# Unnamed: 7                                                               NaN
# Unnamed: 8                                                               NaN
# Unnamed: 9                                                               NaN
# Unnamed: 10                                                              NaN
# Unnamed: 11                                                              NaN
# ...

# %%
#make Second Row AS Header 
df.columns = df.iloc[0]
df = df[1:]
df.head()
display(df)
# Out:
# Open Opportunities Funnel As_of_2021-12-22_17:23:15_India_Standard_Time/IST_•_Generated_by_Aayushi_Lohia  \
# Unnamed: 2                                                               NaN
# Unnamed: 3                                                               NaN
# Unnamed: 4                                                               NaN
# Unnamed: 5                                                               NaN
# Unnamed: 6                                                               NaN
# Unnamed: 7                                                               NaN
# Unnamed: 8                                                               NaN
# Unnamed: 9                                                               NaN
# Unnamed: 10                                                              NaN
# Unnamed: 11                                                              NaN
# Unnamed: 12                                                              NaN
# ...

# %%
#Drop Null Columns
df = df.loc[:, df.columns.notnull()]
display(df)
# Out:
# Open Opportunities Funnel As_of_2021-12-22_17:23:15_India_Standard_Time/IST_•_Generated_by_Aayushi_Lohia  \
# Unnamed: 2                                                               NaN
# Unnamed: 3                                                               NaN
# Unnamed: 4                                                               NaN
# Unnamed: 5                                                               NaN
# Unnamed: 6                                                               NaN
# Unnamed: 7                                                               NaN
# Unnamed: 8                                                               NaN
# Unnamed: 9                                                               NaN
# Unnamed: 10                                                              NaN
# Unnamed: 11                                                              NaN
# Unnamed: 12                                                              NaN
# ...

# %%
#List OF Columns
list(df.columns)
# Out:
# ['As_of_2021-12-22_17:23:15_India_Standard_Time/IST_•_Generated_by_Aayushi_Lohia',
#  'Opportunity:_Opportunity_Owner:_User_Region_→',
#  'Opportunity:_Opportunity_Owner:_Full_Name_→',
#  'Opportunity:_Stage__↑',
#  'Prospect',
#  'Proposal_sent',
#  'Pipeline',
#  'Projection',
#  'Booked',
#  'Total']

# %%
#Ffill Column 1
df["Opportunity:_Opportunity_Owner:_User_Region_→"].fillna(method ='ffill', inplace = True)
df
# Out:
# Open Opportunities Funnel As_of_2021-12-22_17:23:15_India_Standard_Time/IST_•_Generated_by_Aayushi_Lohia  \
# Unnamed: 2                                                               NaN
# Unnamed: 3                                                               NaN
# Unnamed: 4                                                               NaN
# Unnamed: 5                                                               NaN
# Unnamed: 6                                                               NaN
# Unnamed: 7                                                               NaN
# Unnamed: 8                                                               NaN
# Unnamed: 9                                                               NaN
# Unnamed: 10                                                              NaN
# Unnamed: 11                                                              NaN
# Unnamed: 12                                                              NaN
# ...

# %%
#Ffill Column 2
df["Opportunity: Opportunity Owner: User Region →"].fillna(method ='ffill', inplace = True)
df
# Out:
# Open Opportunities Funnel As of 2021-12-22 17:23:15 India Standard Time/IST • Generated by Aayushi Lohia  \
# Unnamed: 2                                                               NaN
# Unnamed: 3                                                               NaN
# Unnamed: 4                                                               NaN
# Unnamed: 5                                                               NaN
# Unnamed: 6                                                               NaN
# Unnamed: 7                                                               NaN
# Unnamed: 8                                                               NaN
# Unnamed: 9                                                               NaN
# Unnamed: 10                                                              NaN
# Unnamed: 11                                                              NaN
# Unnamed: 12                                                              NaN
# ...

# %%
#del Col 2(As_of_2021-12-22_17:23:15_India_Standard_Time)
del df['As_of_2021-12-22_17:23:15_India_Standard_Time/IST_•_Generated_by_Aayushi_Lohia']

# %%
display(df.columns)
# Out:
# Index(['Opportunity:_Opportunity_Owner:_User_Region_→',
#        'Opportunity:_Opportunity_Owner:_Full_Name_→', 'Opportunity:_Stage__↑',
#        'Prospect', 'Proposal_sent', 'Pipeline', 'Projection', 'Booked',
#        'Total'],
#       dtype='object', name='Open Opportunities Funnel')

# %%
display(df)
# Out:
# Open Opportunities Funnel Opportunity:_Opportunity_Owner:_User_Region_→  \
# Unnamed: 2                                                 North & East
# Unnamed: 3                                                 North & East
# Unnamed: 4                                                 North & East
# Unnamed: 5                                                 North & East
# Unnamed: 6                                                 North & East
# Unnamed: 7                                                 North & East
# Unnamed: 8                                                        South
# Unnamed: 9                                                        South
# Unnamed: 10                                                       South
# Unnamed: 11                                                        West
# Unnamed: 12                                                        West
# Unnamed: 13                                                        West
# ...

# %%
display(df.iloc[1])
# Out:
# Open Opportunities Funnel
# Opportunity:_Opportunity_Owner:_User_Region_→                    North & East
# Opportunity:_Opportunity_Owner:_Full_Name_→                    Krishan Sharma
# Opportunity:_Stage__↑                            Sum of Deal Amount(INR Lacs)
# Prospect                                                                    0
# Proposal_sent                                                              10
# Pipeline                                                                   16
# Projection                                                                  0
# Booked                                                                  28.63
# Total                                                                   54.63
# Name: Unnamed: 3, dtype: object

# %%
#TO Take OutPut
df.to_excel("D:\FunctionAppFilesOutput\Output-OpenOpportunitiesFunnel-Dec21.xlsx")

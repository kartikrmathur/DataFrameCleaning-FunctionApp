# %%
import numpy as np
import pandas as pd
import pyspark.pandas as ps

# %%
df = spark.read.format('csv').options(header='true',inferSchema='true').load('/FileStore/tables/Open_Opportunities_Funnel_Jan_22-2.csv')
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
psdf = ps.DataFrame(df)

# %%
list(psdf.columns)
# Out:
# Out[4]: ['_c0',
#  '_c1',
#  '_c2',
#  '_c3',
#  '_c4',
#  '_c5',
#  '_c6',
#  '_c7',
#  '_c8',
#  '_c9',
#  '_c10',
#  '_c11',
#  '_c12',
#  '_c13',
#  '_c14']

# %%
#drop _c0,_c14
psdf = psdf.drop('_c0')
display(psdf)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
psdf = psdf.drop('_c14')
display(psdf)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
display(psdf)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
#transpose on df and store to df
psdf = psdf.transpose()

# %%
display(psdf.iloc[1])
# Out:
# 0                     North & East
# 1                     Dristy Arora
# 2     Sum of Deal Amount(INR Lacs)
# 3                          INR0.00
# 4                          INR0.00
# 5                          INR0.00
# 6                          INR0.00
# 7                         INR39.00
# 8                         INR39.00
# 9                             None
# 10                            None
# Name: _c2, dtype: object

# %%
display(psdf.iloc[0])
# Out:
# 0     Opportunity: Opportunity Owner: User Region →
# 1       Opportunity: Opportunity Owner: Full Name →
# 2                             Opportunity: Stage  ↑
# 3                                          Prospect
# 4                                     Proposal sent
# 5                                          Pipeline
# 6                                        Projection
# 7                                            Booked
# 8                                             Total
# 9                                              None
# 10                                             None
# Name: _c1, dtype: object

# %%
psdf = psdf.ffill()
display(psdf)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
psdf = psdf.drop(9)
display(psdf)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
psdf = psdf.drop(10)
display(psdf)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
psdf
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#       <th>4</th>
#       <th>5</th>
#       <th>6</th>
#       <th>7</th>
#       <th>8</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>_c1</th>
#       <td>Opportunity: Opportunity Owner: User Region →</td>
#       <td>Opportunity: Opportunity Owner: Full Name →</td>
#       <td>Opportunity: Stage  ↑</td>
#       <td>Prospect</td>
#       <td>Proposal sent</td>
#       <td>Pipeline</td>
#       <td>Projection</td>
#       <td>Booked</td>
#       <td>Total</td>
#     </tr>
#     <tr>
#       <th>_c2</th>
# ...

# %%
header_row = 1
psdf.columns = psdf.iloc[0]
display(psdf)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

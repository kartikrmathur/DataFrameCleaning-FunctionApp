# %%
import pandas as pd
import numpy as np
#make df
df = pd.read_excel(r'D:\Function App Files\DSR - Meetings log- all time-Apr-21st Dec.xlsx',header = 1)
display(df)
# Out:
#       Unnamed: 0 Activity User Region  ↑ Attendee type  ↑    Date  ↑  \
# 0            NaN            North & East           Client   5/4/2021
# 1            NaN                     NaN              NaN   6/4/2021
# 2            NaN                     NaN              NaN        NaN
# 3            NaN                     NaN              NaN   7/4/2021
# 4            NaN                     NaN              NaN  12/4/2021
# ...          ...                     ...              ...        ...
# 3897         NaN                     NaN              NaN        NaN
# 3898         NaN                     NaN              NaN  7/12/2021
# 3899         NaN                     NaN              NaN        NaN
# 3900         NaN                     NaN              NaN  9/12/2021
# 3901         NaN                     NaN              NaN        NaN
#
#       Unnamed: 4                                  Related To  \
# 0            NaN                                  TINDER INC
# ...

# %%
#drop null
df = df.dropna(how='all')
display(df)
# Out:
#       Unnamed: 0 Activity User Region  ↑ Attendee type  ↑    Date  ↑  \
# 0            NaN            North & East           Client   5/4/2021
# 1            NaN                     NaN              NaN   6/4/2021
# 2            NaN                     NaN              NaN        NaN
# 3            NaN                     NaN              NaN   7/4/2021
# 4            NaN                     NaN              NaN  12/4/2021
# ...          ...                     ...              ...        ...
# 3897         NaN                     NaN              NaN        NaN
# 3898         NaN                     NaN              NaN  7/12/2021
# 3899         NaN                     NaN              NaN        NaN
# 3900         NaN                     NaN              NaN  9/12/2021
# 3901         NaN                     NaN              NaN        NaN
#
#       Unnamed: 4                                  Related To  \
# 0            NaN                                  TINDER INC
# ...

# %%
#List OF Columns
list(df.columns)
# Out:
# ['Unnamed: 0',
#  'Activity User Region  ↑',
#  'Attendee type  ↑',
#  'Date  ↑',
#  'Unnamed: 4',
#  'Related To',
#  'Agency',
#  'Contact',
#  'Subject',
#  'Assigned',
#  'Comments',
#  'Account Type',
#  'Unnamed: 12']

# %%
del df['Unnamed: 0']

# %%
del df['Unnamed: 4']

# %%
del df['Unnamed: 12']

# %%
display(df)
# Out:
#      Activity User Region  ↑ Attendee type  ↑    Date  ↑  \
# 0               North & East           Client   5/4/2021
# 1                        NaN              NaN   6/4/2021
# 2                        NaN              NaN        NaN
# 3                        NaN              NaN   7/4/2021
# 4                        NaN              NaN  12/4/2021
# ...                      ...              ...        ...
# 3897                     NaN              NaN        NaN
# 3898                     NaN              NaN  7/12/2021
# 3899                     NaN              NaN        NaN
# 3900                     NaN              NaN  9/12/2021
# 3901                     NaN              NaN        NaN
#
#                                       Related To               Agency  \
# 0                                     TINDER INC            Wavemaker
# 1     Tictok Skill Games Private Limited (WINZO)    Direct Advertiser
# ...

# %%
#Ffill Column 1
df["Activity User Region  ↑"].fillna(method ='ffill', inplace = True)
df
# Out:
#      Activity User Region  ↑ Attendee type  ↑    Date  ↑  \
# 0               North & East           Client   5/4/2021
# 1               North & East              NaN   6/4/2021
# 2               North & East              NaN        NaN
# 3               North & East              NaN   7/4/2021
# 4               North & East              NaN  12/4/2021
# ...                      ...              ...        ...
# 3897                    West              NaN        NaN
# 3898                    West              NaN  7/12/2021
# 3899                    West              NaN        NaN
# 3900                    West              NaN  9/12/2021
# 3901                    West              NaN        NaN
#
#                                       Related To               Agency  \
# 0                                     TINDER INC            Wavemaker
# 1     Tictok Skill Games Private Limited (WINZO)    Direct Advertiser
# ...

# %%
#Ffill Column 2
df["Attendee type  ↑"].fillna(method ='ffill', inplace = True)
df
# Out:
#      Activity User Region  ↑ Attendee type  ↑    Date  ↑  \
# 0               North & East           Client   5/4/2021
# 1               North & East           Client   6/4/2021
# 2               North & East           Client        NaN
# 3               North & East           Client   7/4/2021
# 4               North & East           Client  12/4/2021
# ...                      ...              ...        ...
# 3897                    West  Client & Agency        NaN
# 3898                    West  Client & Agency  7/12/2021
# 3899                    West  Client & Agency        NaN
# 3900                    West  Client & Agency  9/12/2021
# 3901                    West  Client & Agency        NaN
#
#                                       Related To               Agency  \
# 0                                     TINDER INC            Wavemaker
# 1     Tictok Skill Games Private Limited (WINZO)    Direct Advertiser
# ...

# %%
#Ffill Column 3
df["Date  ↑"].fillna(method ='ffill', inplace = True)
df
# Out:
#      Activity User Region  ↑ Attendee type  ↑     Date  ↑  \
# 0               North & East           Client    5/4/2021
# 1               North & East           Client    6/4/2021
# 2               North & East           Client    6/4/2021
# 3               North & East           Client    7/4/2021
# 4               North & East           Client   12/4/2021
# ...                      ...              ...         ...
# 3897                    West  Client & Agency  25/11/2021
# 3898                    West  Client & Agency   7/12/2021
# 3899                    West  Client & Agency   7/12/2021
# 3900                    West  Client & Agency   9/12/2021
# 3901                    West  Client & Agency   9/12/2021
#
#                                       Related To               Agency  \
# 0                                     TINDER INC            Wavemaker
# 1     Tictok Skill Games Private Limited (WINZO)    Direct Advertiser
# ...

# %%
#Ffill Column 3
df["Agency"].fillna(method ='ffill', inplace = True)
df
# Out:
#      Activity User Region  ↑ Attendee type  ↑     Date  ↑  \
# 0               North & East           Client    5/4/2021
# 1               North & East           Client    6/4/2021
# 2               North & East           Client    6/4/2021
# 3               North & East           Client    7/4/2021
# 4               North & East           Client   12/4/2021
# ...                      ...              ...         ...
# 3897                    West  Client & Agency  25/11/2021
# 3898                    West  Client & Agency   7/12/2021
# 3899                    West  Client & Agency   7/12/2021
# 3900                    West  Client & Agency   9/12/2021
# 3901                    West  Client & Agency   9/12/2021
#
#                                       Related To               Agency  \
# 0                                     TINDER INC            Wavemaker
# 1     Tictok Skill Games Private Limited (WINZO)    Direct Advertiser
# ...

# %%
#Ffill Column 3
df["Contact"].fillna(method ='ffill', inplace = True)
df
# Out:
#      Activity User Region  ↑ Attendee type  ↑     Date  ↑  \
# 0               North & East           Client    5/4/2021
# 1               North & East           Client    6/4/2021
# 2               North & East           Client    6/4/2021
# 3               North & East           Client    7/4/2021
# 4               North & East           Client   12/4/2021
# ...                      ...              ...         ...
# 3897                    West  Client & Agency  25/11/2021
# 3898                    West  Client & Agency   7/12/2021
# 3899                    West  Client & Agency   7/12/2021
# 3900                    West  Client & Agency   9/12/2021
# 3901                    West  Client & Agency   9/12/2021
#
#                                       Related To               Agency  \
# 0                                     TINDER INC            Wavemaker
# 1     Tictok Skill Games Private Limited (WINZO)    Direct Advertiser
# ...

# %%
#TO Take OutPut
df.to_excel("D:\FunctionAppFilesOutput\Output-DSR - Meetings log- all time-Apr-21st Dec.xlsx.xlsx")

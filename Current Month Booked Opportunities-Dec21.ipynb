# %%
#Library Importings
import pandas as pd
import numpy as np

# %%
#calling Of Our Dataframes
df = pd.read_excel(r'D:\Function App Files\Current Month Booked Opportunities-Dec21.xlsx',header = 2)
display(df)
# Out:
#      Unnamed: 0 Opportunity Owner  ↑ Company Name  ↑ Unnamed: 3  \
# 0           NaN        Asmita Shukla      SKODA AUTO        NaN
# 1           NaN                  NaN        Subtotal        Sum
# 2           NaN                  NaN             NaN        Avg
# 3           NaN                  NaN             NaN      Count
# 4           NaN             Subtotal             NaN        Sum
# ..          ...                  ...             ...        ...
# 180         NaN                  NaN             NaN        Avg
# 181         NaN                  NaN             NaN      Count
# 182         NaN             Subtotal             NaN        Sum
# 183         NaN                  NaN             NaN        Avg
# 184         NaN                  NaN             NaN      Count
#
#      Opportunity Amount (INR Lacs)  Unnamed: 5
# 0                          16.6700         NaN
# 1                          16.6700         NaN
# 2                          16.6700         NaN
# ...

# %%
#Displaying Our Data Frame And Dropping Nulls
df1 = df.dropna(how='all',axis=1)
display(df1)
# Out:
#     Opportunity Owner  ↑ Company Name  ↑ Unnamed: 3  \
# 0          Asmita Shukla      SKODA AUTO        NaN
# 1                    NaN        Subtotal        Sum
# 2                    NaN             NaN        Avg
# 3                    NaN             NaN      Count
# 4               Subtotal             NaN        Sum
# ..                   ...             ...        ...
# 180                  NaN             NaN        Avg
# 181                  NaN             NaN      Count
# 182             Subtotal             NaN        Sum
# 183                  NaN             NaN        Avg
# 184                  NaN             NaN      Count
#
#      Opportunity Amount (INR Lacs)
# 0                          16.6700
# 1                          16.6700
# 2                          16.6700
# 3                           1.0000
# 4                          16.6700
# ..                             ...
# 180                        46.3500
# 181                         1.0000
# ...

# %%
#Info Of Our Columns 
display(df1.columns)
# Out:
# Index(['Opportunity Owner  ↑', 'Company Name  ↑', 'Unnamed: 3',
#        'Opportunity Amount (INR Lacs)'],
#       dtype='object')

# %%
#FFiling OF Opportunity Owner 
df1["Opportunity Owner  ↑"].fillna(method ='ffill', inplace = True)
df1
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py:4463: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(
#     Opportunity Owner  ↑ Company Name  ↑ Unnamed: 3  \
# 0          Asmita Shukla      SKODA AUTO        NaN
# 1          Asmita Shukla        Subtotal        Sum
# 2          Asmita Shukla             NaN        Avg
# 3          Asmita Shukla             NaN      Count
# 4               Subtotal             NaN        Sum
# ..                   ...             ...        ...
# 180          Somil Kumar             NaN        Avg
# 181          Somil Kumar             NaN      Count
# 182             Subtotal             NaN        Sum
# 183             Subtotal             NaN        Avg
# 184             Subtotal             NaN      Count
#
# ...

# %%
#making of Our Column (Sum And Average)

df1['Sum'] = ''
df1['Avg'] = ''
df1
# Out:
# <ipython-input-14-b83c9deb491f>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Sum'] = ''
#     Opportunity Owner  ↑ Company Name  ↑ Unnamed: 3  \
# 0          Asmita Shukla      SKODA AUTO        NaN
# 1          Asmita Shukla        Subtotal        Sum
# 2          Asmita Shukla             NaN        Avg
# 3          Asmita Shukla             NaN      Count
# 4               Subtotal             NaN        Sum
# ..                   ...             ...        ...
# 180          Somil Kumar             NaN        Avg
# 181          Somil Kumar             NaN      Count
# 182             Subtotal             NaN        Sum
# 183             Subtotal             NaN        Avg
# ...

# %%
df1.to_excel("D:\FunctionAppFilesOutput\8JanWork.xlsx")

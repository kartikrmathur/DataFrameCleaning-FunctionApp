# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel(r'D:\Function App Files\Current Month Initiated Opportunities-Dec21.xlsx',header = 1)
display(df)
# Out:
#      Unnamed: 0            Unnamed: 1              Unnamed: 2  \
# 0           NaN  Opportunity Owner  ↑         Company Name  ↑
# 1           NaN         Asmita Shukla     HINDUSTAN LEVER LTD
# 2           NaN                   NaN              SKODA AUTO
# 3           NaN              Subtotal                     NaN
# 4           NaN          Dristy Arora  American Airlines Inc.
# ..          ...                   ...                     ...
# 121         NaN                   NaN    THE HIMALAYA DRUG CO
# 122         NaN                   NaN   THINK & LEARN PVT LTD
# 123         NaN                   NaN                 VEDANTU
# 124         NaN              Subtotal                     NaN
# 125         NaN                 Total                     NaN
#
#                                Unnamed: 3  \
# 0    Sum of Opportunity Amount (INR Lacs)
# 1                                      30
# 2                                   16.67
# 3                                   46.67
# ...

# %%
df = df.dropna(how='all')
df = df.dropna(how='all', axis=1)
display(df)
# Out:
#                Unnamed: 1              Unnamed: 2  \
# 0    Opportunity Owner  ↑         Company Name  ↑
# 1           Asmita Shukla     HINDUSTAN LEVER LTD
# 2                     NaN              SKODA AUTO
# 3                Subtotal                     NaN
# 4            Dristy Arora  American Airlines Inc.
# ..                    ...                     ...
# 121                   NaN    THE HIMALAYA DRUG CO
# 122                   NaN   THINK & LEARN PVT LTD
# 123                   NaN                 VEDANTU
# 124              Subtotal                     NaN
# 125                 Total                     NaN
#
#                                Unnamed: 3  \
# 0    Sum of Opportunity Amount (INR Lacs)
# 1                                      30
# 2                                   16.67
# 3                                   46.67
# 4                                     3.5
# ..                                    ...
# 121                                    10
# ...

# %%
#make Second Row AS Header 
df.columns = df.iloc[0]
df = df[1:]
df.head()
display(df)
# Out:
# 0   Opportunity Owner  ↑         Company Name  ↑  \
# 1          Asmita Shukla     HINDUSTAN LEVER LTD
# 2                    NaN              SKODA AUTO
# 3               Subtotal                     NaN
# 4           Dristy Arora  American Airlines Inc.
# 5                    NaN           EMAMI LIMITED
# ..                   ...                     ...
# 121                  NaN    THE HIMALAYA DRUG CO
# 122                  NaN   THINK & LEARN PVT LTD
# 123                  NaN                 VEDANTU
# 124             Subtotal                     NaN
# 125                Total                     NaN
#
# 0   Sum of Opportunity Amount (INR Lacs)  \
# 1                                     30
# 2                                  16.67
# 3                                  46.67
# 4                                    3.5
# 5                                     20
# ..                                   ...
# 121                                   10
# ...

# %%
#List OF Columns
list(df.columns)
# Out:
# ['Opportunity Owner  ↑',
#  'Company Name  ↑',
#  'Sum of Opportunity Amount (INR Lacs)',
#  'Average Opportunity Amount (INR Lacs)',
#  'Record Count']

# %%
#Ffill Column 1
df["Opportunity Owner  ↑"].fillna(method ='ffill', inplace = True)
df
# Out:
# 0   Opportunity Owner  ↑         Company Name  ↑  \
# 1          Asmita Shukla     HINDUSTAN LEVER LTD
# 2          Asmita Shukla              SKODA AUTO
# 3               Subtotal                     NaN
# 4           Dristy Arora  American Airlines Inc.
# 5           Dristy Arora           EMAMI LIMITED
# ..                   ...                     ...
# 121          Somil Kumar    THE HIMALAYA DRUG CO
# 122          Somil Kumar   THINK & LEARN PVT LTD
# 123          Somil Kumar                 VEDANTU
# 124             Subtotal                     NaN
# 125                Total                     NaN
#
# 0   Sum of Opportunity Amount (INR Lacs)  \
# 1                                     30
# 2                                  16.67
# 3                                  46.67
# 4                                    3.5
# 5                                     20
# ..                                   ...
# 121                                   10
# ...

# %%
#Ffill Column 1
df["Company Name  ↑"].fillna(method ='ffill', inplace = True)
df
# Out:
# 0   Opportunity Owner  ↑         Company Name  ↑  \
# 1          Asmita Shukla     HINDUSTAN LEVER LTD
# 2          Asmita Shukla              SKODA AUTO
# 3               Subtotal              SKODA AUTO
# 4           Dristy Arora  American Airlines Inc.
# 5           Dristy Arora           EMAMI LIMITED
# ..                   ...                     ...
# 121          Somil Kumar    THE HIMALAYA DRUG CO
# 122          Somil Kumar   THINK & LEARN PVT LTD
# 123          Somil Kumar                 VEDANTU
# 124             Subtotal                 VEDANTU
# 125                Total                 VEDANTU
#
# 0   Sum of Opportunity Amount (INR Lacs)  \
# 1                                     30
# 2                                  16.67
# 3                                  46.67
# 4                                    3.5
# 5                                     20
# ..                                   ...
# 121                                   10
# ...

# %%
#TO Take OutPut
df.to_excel("D:\FunctionAppFilesOutput\Output-Current Month Initiated Opportunities-Dec21.xlsx")

# %%
import pandas as pd
import numpy as np
import pandasql as ps

# %%
df = pd.read_excel(r'D:\Function App Files\Account List Regionwise.xlsx',header = 1)
display(df)
# Out:
#       Unnamed: 0  Region   Account Owner: Full Name   Unnamed: 3  \
# 0            NaN      West              Aayushi Kedia        NaN
# 1            NaN       NaN                        NaN        NaN
# 2            NaN       NaN                        NaN        NaN
# 3            NaN       NaN                        NaN        NaN
# 4            NaN       NaN                   Subtotal      Count
# ...          ...       ...                        ...        ...
# 1273         NaN       NaN                   Subtotal      Count
# 1274         NaN       NaN                Sumit Anand        NaN
# 1275         NaN       NaN                   Subtotal      Count
# 1276         NaN  Subtotal                        NaN      Count
# 1277         NaN     Total                        NaN      Count
#
#                                           Company Name  Unnamed: 5
# 0                                         FitCircle.in         NaN
# ...

# %%
df1 = df.dropna(how='all')
df1 = df.dropna(how='all', axis=1)
display(df1)
# Out:
#       Region   Account Owner: Full Name   Unnamed: 3  \
# 0         West              Aayushi Kedia        NaN
# 1          NaN                        NaN        NaN
# 2          NaN                        NaN        NaN
# 3          NaN                        NaN        NaN
# 4          NaN                   Subtotal      Count
# ...        ...                        ...        ...
# 1273       NaN                   Subtotal      Count
# 1274       NaN                Sumit Anand        NaN
# 1275       NaN                   Subtotal      Count
# 1276  Subtotal                        NaN      Count
# 1277     Total                        NaN      Count
#
#                                           Company Name
# 0                                         FitCircle.in
# 1                           Aesthetic Apparels Pvt Ltd
# 2                    Social Worth Technologies Pvt Ltd
# 3                                             Elsa Co.
# ...

# %%
display(df.columns)
# Out:
# Index(['Unnamed: 0', 'Region  ', 'Account Owner: Full Name  ', 'Unnamed: 3',
#        'Company Name', 'Unnamed: 5'],
#       dtype='object')

# %%
list(df1.columns)
# Out:
# ['Region  ', 'Account Owner: Full Name  ', 'Unnamed: 3', 'Company Name']

# %%
df1["Region  "].fillna(method ='ffill', inplace = True)
df1
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py:4463: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(
#           Region   Account Owner: Full Name   Unnamed: 3  \
# 0             West              Aayushi Kedia        NaN
# 1             West                        NaN        NaN
# 2             West                        NaN        NaN
# 3             West                        NaN        NaN
# 4             West                   Subtotal      Count
# ...            ...                        ...        ...
# 1273  North & East                   Subtotal      Count
# 1274  North & East                Sumit Anand        NaN
# 1275  North & East                   Subtotal      Count
# 1276      Subtotal                        NaN      Count
# ...

# %%
df1["Account Owner: Full Name  "].fillna(method ='ffill', inplace = True)
df1
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py:4463: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(
#           Region   Account Owner: Full Name   Unnamed: 3  \
# 0             West              Aayushi Kedia        NaN
# 1             West              Aayushi Kedia        NaN
# 2             West              Aayushi Kedia        NaN
# 3             West              Aayushi Kedia        NaN
# 4             West                   Subtotal      Count
# ...            ...                        ...        ...
# 1273  North & East                   Subtotal      Count
# 1274  North & East                Sumit Anand        NaN
# 1275  North & East                   Subtotal      Count
# 1276      Subtotal                   Subtotal      Count
# ...

# %%
df1["Company Name"].fillna(method ='ffill', inplace = True)
display(df1)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py:4463: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(
#           Region   Account Owner: Full Name   Unnamed: 3  \
# 0             West              Aayushi Kedia        NaN
# 1             West              Aayushi Kedia        NaN
# 2             West              Aayushi Kedia        NaN
# 3             West              Aayushi Kedia        NaN
# 4             West                   Subtotal      Count
# ...            ...                        ...        ...
# 1273  North & East                   Subtotal      Count
# 1274  North & East                Sumit Anand        NaN
# 1275  North & East                   Subtotal      Count
# 1276      Subtotal                   Subtotal      Count
# ...

# %%
df1.Unnamed: 3 = df1['Unnamed: 3'].replace(np.nan, 'Count')
display(df1)
# Out:
# <ipython-input-9-e95b06e7bae4>:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df1.Unnamed: 3 = df1['Unnamed: 3'].replace(np.nan, 'Count')
#           Region   Account Owner: Full Name   Unnamed: 3  \
# 0             West              Aayushi Kedia        NaN
# 1             West              Aayushi Kedia        NaN
# 2             West              Aayushi Kedia        NaN
# 3             West              Aayushi Kedia        NaN
# 4             West                   Subtotal      Count
# ...            ...                        ...        ...
# 1273  North & East                   Subtotal      Count
# 1274  North & East                Sumit Anand        NaN
# 1275  North & East                   Subtotal      Count
# 1276      Subtotal                   Subtotal      Count
# 1277         Total                   Subtotal      Count
#
# ...

# %%
df1["Unnamed: 3"].fillna(method ='bfill', inplace = True)
display(df1)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py:4463: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(
#           Region   Account Owner: Full Name   Unnamed: 3  \
# 0             West              Aayushi Kedia      Count
# 1             West              Aayushi Kedia      Count
# 2             West              Aayushi Kedia      Count
# 3             West              Aayushi Kedia      Count
# 4             West                   Subtotal      Count
# ...            ...                        ...        ...
# 1273  North & East                   Subtotal      Count
# 1274  North & East                Sumit Anand      Count
# 1275  North & East                   Subtotal      Count
# 1276      Subtotal                   Subtotal      Count
# ...

# %%
df1.to_excel("D:\FunctionAppFilesOutput\OutPut-AccountListRegionWiseoutput.xlsx")

# %%
q1 = """ SELECT * FROM df1 """
print(ps.sqldf(q1, locals()))
# Out:
#           Region   Account Owner: Full Name   Unnamed: 3  \
# 0             West              Aayushi Kedia      Count
# 1             West              Aayushi Kedia      Count
# 2             West              Aayushi Kedia      Count
# 3             West              Aayushi Kedia      Count
# 4             West                   Subtotal      Count
# ...            ...                        ...        ...
# 1273  North & East                   Subtotal      Count
# 1274  North & East                Sumit Anand      Count
# 1275  North & East                   Subtotal      Count
# 1276      Subtotal                   Subtotal      Count
# 1277         Total                   Subtotal      Count
#
#                                           Company Name
# 0                                         FitCircle.in
# 1                           Aesthetic Apparels Pvt Ltd
# 2                    Social Worth Technologies Pvt Ltd
# 3                                             Elsa Co.
# ...

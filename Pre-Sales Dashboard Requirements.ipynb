# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel(r'D:\Function App Files\Pre-Sales Dashboard Requirements.xlsx',header = 1)
display(df)
# Out:
#                                Region Filter  \
# 0                                  AM Filter
# 1                               Month Filter
# 2                                Week Filter
# 3                             Total Meetings
# 4                            Unique Meetings
# 5                            Client Meetings
# 6                            Agency Meetings
# 7                      No. of proposals sent
# 8                    Total Value of proposal
# 9            Projected Closure for the Month
# 10                       Coverage This month
# 11                     Conversion This month
# 12                  Week wise meetings trend
# 13                   Day wise meetings trend
# 14                 Current/Next Month Funnel
# 15  Top Clients - Booked/Projection/Pipeline
#
#        Multi Select - North&East, South, West, Studio  \
# 0                                        Multi Select
# 1                                        Multi Select
# ...

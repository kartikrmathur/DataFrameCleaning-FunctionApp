# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel(r'D:\Function App Files\Top Clients - By Start Date-Dec21.xlsx',header = 1)
display(df)
# Out:
#     Unnamed: 0  Stage  ↑                        Company Name  ↑ Unnamed: 3  \
# 0          NaN  Pipeline                              AMAZON.IN        NaN
# 1          NaN       NaN                      BHARTI AIRTEL LTD        NaN
# 2          NaN       NaN                      Direct Advertiser        NaN
# 3          NaN       NaN                                    NaN        NaN
# 4          NaN       NaN          GOKULDAS INTIMATEWEAR PVT LTD        NaN
# ..         ...       ...                                    ...        ...
# 75         NaN       NaN          YUM RESTAURANTS INDIA PVT LTD        NaN
# 76         NaN       NaN  ZEE ENTERTAINMENT ENTERPRISES LIMITED        NaN
# 77         NaN     Total                                    NaN        Sum
# 78         NaN       NaN                                    NaN        Avg
# 79         NaN       NaN                                    NaN      Count
#
#    Opportunity Owner  Opportunity Amount (INR Lacs)  Unnamed: 6
# ...

# %%
df = df.dropna(how='all')
df = df.dropna(how='all', axis=1)
display(df)
# Out:
#     Stage  ↑                        Company Name  ↑ Unnamed: 3  \
# 0   Pipeline                              AMAZON.IN        NaN
# 1        NaN                      BHARTI AIRTEL LTD        NaN
# 2        NaN                      Direct Advertiser        NaN
# 3        NaN                                    NaN        NaN
# 4        NaN          GOKULDAS INTIMATEWEAR PVT LTD        NaN
# ..       ...                                    ...        ...
# 75       NaN          YUM RESTAURANTS INDIA PVT LTD        NaN
# 76       NaN  ZEE ENTERTAINMENT ENTERPRISES LIMITED        NaN
# 77     Total                                    NaN        Sum
# 78       NaN                                    NaN        Avg
# 79       NaN                                    NaN      Count
#
#    Opportunity Owner  Opportunity Amount (INR Lacs)
# 0        Somil Kumar                      50.000000
# 1     Krishan Sharma                      10.000000
# ...

# %%
#List OF Columns
list(df.columns)
# Out:
# ['Stage  ↑',
#  'Company Name  ↑',
#  'Unnamed: 3',
#  'Opportunity Owner',
#  'Opportunity Amount (INR Lacs)']

# %%
#Ffill Column 1
df["Stage  ↑"].fillna(method ='ffill', inplace = True)
df
# Out:
#     Stage  ↑                        Company Name  ↑ Unnamed: 3  \
# 0   Pipeline                              AMAZON.IN        NaN
# 1   Pipeline                      BHARTI AIRTEL LTD        NaN
# 2   Pipeline                      Direct Advertiser        NaN
# 3   Pipeline                                    NaN        NaN
# 4   Pipeline          GOKULDAS INTIMATEWEAR PVT LTD        NaN
# ..       ...                                    ...        ...
# 75    Booked          YUM RESTAURANTS INDIA PVT LTD        NaN
# 76    Booked  ZEE ENTERTAINMENT ENTERPRISES LIMITED        NaN
# 77     Total                                    NaN        Sum
# 78     Total                                    NaN        Avg
# 79     Total                                    NaN      Count
#
#    Opportunity Owner  Opportunity Amount (INR Lacs)
# 0        Somil Kumar                      50.000000
# 1     Krishan Sharma                      10.000000
# ...

# %%
#Ffill Column 1
df["Company Name  ↑"].fillna(method ='ffill', inplace = True)
df
# Out:
#     Stage  ↑                        Company Name  ↑ Unnamed: 3  \
# 0   Pipeline                              AMAZON.IN        NaN
# 1   Pipeline                      BHARTI AIRTEL LTD        NaN
# 2   Pipeline                      Direct Advertiser        NaN
# 3   Pipeline                      Direct Advertiser        NaN
# 4   Pipeline          GOKULDAS INTIMATEWEAR PVT LTD        NaN
# ..       ...                                    ...        ...
# 75    Booked          YUM RESTAURANTS INDIA PVT LTD        NaN
# 76    Booked  ZEE ENTERTAINMENT ENTERPRISES LIMITED        NaN
# 77     Total  ZEE ENTERTAINMENT ENTERPRISES LIMITED        Sum
# 78     Total  ZEE ENTERTAINMENT ENTERPRISES LIMITED        Avg
# 79     Total  ZEE ENTERTAINMENT ENTERPRISES LIMITED      Count
#
#    Opportunity Owner  Opportunity Amount (INR Lacs)
# 0        Somil Kumar                      50.000000
# 1     Krishan Sharma                      10.000000
# ...

# %%
print(df, '\n')
# Out:
#     Stage  ↑                        Company Name  ↑ Unnamed: 3  \
# 0   Pipeline                              AMAZON.IN        NaN
# 1   Pipeline                      BHARTI AIRTEL LTD        NaN
# 2   Pipeline                      Direct Advertiser        NaN
# 3   Pipeline                      Direct Advertiser        NaN
# 4   Pipeline          GOKULDAS INTIMATEWEAR PVT LTD        NaN
# ..       ...                                    ...        ...
# 75    Booked          YUM RESTAURANTS INDIA PVT LTD        NaN
# 76    Booked  ZEE ENTERTAINMENT ENTERPRISES LIMITED        NaN
# 77     Total  ZEE ENTERTAINMENT ENTERPRISES LIMITED        Sum
# 78     Total  ZEE ENTERTAINMENT ENTERPRISES LIMITED        Avg
# 79     Total  ZEE ENTERTAINMENT ENTERPRISES LIMITED      Count
#
#    Opportunity Owner  Opportunity Amount (INR Lacs)
# 0        Somil Kumar                      50.000000
# 1     Krishan Sharma                      10.000000
# ...

# %%
#JOIN TWO TABLES

# %%
#TO Take OutPut
df.to_excel("D:\FunctionAppFilesOutput\Output-Top Clients - By Start Date-Dec21.xlsx")
